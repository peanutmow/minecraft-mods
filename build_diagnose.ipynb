# %% [markdown]
# # Build Failure Diagnosis
# Read build logs and inspect relevant source files.

# %%
import pathlib
from pathlib import Path
import json
import os
import subprocess

# %%
root = Path('c:/Users/dherk/Desktop/Minecraft/minecraft-mods/ZV_basics')
print('root exists:', root.exists())
log_path = root / 'gradle-build.log'
print('log exists:', log_path.exists())
if log_path.exists():
    data = log_path.read_bytes()
    try:
        text = data.decode('utf-8')
    except UnicodeDecodeError:
        text = data.decode('utf-16', errors='replace')
    print(text[:5000])
